# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelmathew280/OOP/blob/main/OOP_Lab_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def isLeapYear(year):
  if year%400 == 0:
    return True
  elif year%4 == 0 and year%100 !=0:
    return True
  else:
    return False
years = [200, 480, 2800, 3000]
for year in years:
  if isLeapYear(year) == True:
    print("{0} is a leap year".format(year))
  else:
    print("{0} is not a leap year".format(year))
# Out:
# 200 is not a leap year
# 480 is a leap year
# 2800 is a leap year
# 3000 is not a leap year

# %%
def isWeird(num):
  if num%2 != 0:
    print("Weird")
  elif num%2 == 0 and num in range(2,6):
    print("Not Weird")
  elif num%2 == 0 and num in range (6,21):
    print("Weird")
  elif num%2 == 0 and num>20:
    print("Not Weird")
  else:
    print("Unspecified.")

isWeird(20)
# Out:
# Weird

# %%
def isFashionablyLate(guests, guest):
  mid = int(len(guests)/2) - 1    #As mid represents index, not position, we subtract 1
  k = 0
  guestIndex = None
  for i in guests:
    if i == guest:
      guestIndex = k
      break
    k+=1
  if guestIndex != None:
    if guestIndex > mid and guestIndex != len(guests)-1:
      print("{0} is fashionably late.".format(guest))
    else:
      print("{0} isn't fashionably late.".format(guest))
  else:
    print("Name is not present in the guest list.") 

Arrivals = ['Hardik', 'Rahul', 'Virat', 'Rishabh', 'Mahi', 'Rohit', 'Rahane']
isFashionablyLate(Arrivals, 'Virat')
isFashionablyLate(Arrivals, 'Rishabh')
isFashionablyLate(Arrivals, 'Rahane')
# Out:
# Virat isn't fashionably late.
# Rishabh is fashionably late.
# Rahane isn't fashionably late.

# %%
import re
def filterDocs(articles, term):
  newList = []
  for i in articles:
    cleanText = re.sub(r'[^A-Za-z0-9 ]+', '', i)
    if cleanText.lower().count(term.lower()) > 0:
      words = cleanText.split()
      words = [x.lower() for x in words]
      if term.lower() in words:
        newList.append(i)
  return newList

doc_list = ['The Learning Python Challenge Rohit.', 'They bought a car.', "Rohit's adventures", "python libraries", "bangalore"]
print(filterDocs(doc_list, 'Rohit'))
print(filterDocs(doc_list, 'Python'))
# Out:
# ['The Learning Python Challenge Rohit.']
# ['The Learning Python Challenge Rohit.', 'python librariesbangalore']

# %%
def grossPay(BP):
  DA = 0.4*BP
  GRA = 0.2*BP
  return BP+DA+GRA
BP = int(input("Enter your basic pay: "))
print("Gross pay is: {0}".format(grossPay(BP)))
# Out:
# Enter your basic pay: 1200
# Gross pay is: 1920.0
